# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/quikr_car.csv')
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
df.shape
# Out:
# (892, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
df['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
# ...

# %%
df['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
df['year']
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 887    zest
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 892, dtype: object

# %%
df[df['year'].str.isnumeric()]
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
df['Price']
# Out:
# 0             80,000
# 1           4,25,000
# 2      Ask For Price
# 3           3,25,000
# 4           5,75,000
#            ...
# 887         3,10,000
# 888         2,60,000
# 889         3,90,000
# 890         1,80,000
# 891         1,60,000
# Name: Price, Length: 892, dtype: object

# %%
df[df['Price']!='Ask For Price']
# Out:
#                                        name    company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  4,25,000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  5,75,000
# 6                                 Ford Figo       Ford  2012  1,75,000
# ..                                      ...        ...   ...       ...
# 887                                      Ta       Tara  zest  3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018  2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013  3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# 1        40 kms    Diesel
# 3    28,000 kms    Petrol
# ...

# %%
df['Price']
# Out:
# 0        80,000
# 1      4,25,000
# 3      3,25,000
# 4      5,75,000
# 6      1,75,000
#          ...
# 887    3,10,000
# 888    2,60,000
# 889    3,90,000
# 890    1,80,000
# 891    1,60,000
# Name: Price, Length: 857, dtype: object

# %%
df['Price']=df['Price'].str.replace(',','').astype(int)
# Out:
# <ipython-input-25-6c07cc7499ae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=df['Price'].str.replace(',','').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 857 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        857 non-null    object
#  1   company     857 non-null    object
#  2   year        857 non-null    object
#  3   Price       857 non-null    int64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 46.9+ KB

# %%
df['kms_driven']
# Out:
# 0      45,000 kms
# 1          40 kms
# 3      28,000 kms
# 4      36,000 kms
# 6      41,000 kms
#           ...
# 887           NaN
# 888    27,000 kms
# 889    40,000 kms
# 890        Petrol
# 891        Petrol
# Name: kms_driven, Length: 857, dtype: object

# %%
df['kms_driven']=df['kms_driven'].str.split().str.get(0)
# Out:
# <ipython-input-32-36afc17db2a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kms_driven']=df['kms_driven'].str.split().str.get(0)

# %%
df
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 6                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 887                                      Ta       Tara  zest  310000
# 888                     Tata Zest XM Diesel       Tata  2018  260000
# 889                      Mahindra Quanto C8   Mahindra  2013  390000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#     kms_driven fuel_type
# 0       45,000    Petrol
# 1           40    Diesel
# 3       28,000    Petrol
# 4       36,000    Diesel
# ...

# %%
df[df['fuel_type'].isna()]
# Out:
#                                        name     company  year   Price  \
# 132                          Toyota Corolla      Toyota  2009  275000
# 195                 Tata indigo ecs LX, 201        Tata  150k  150000
# 206                      MARUTI SUZUKI DESI      MARUTI  TOUR  400000
# 294                                    Yama      Yamaha  r 15   55000
# 385           Maruti Suzuki Swift Dzire car      Maruti  sale  300000
# 395     Maruti Suzuki Swift Dzire Tour (Gat      Maruti  ara)  300000
# 401                                    URJE      URJENT  SELL  180000
# 414      Swift Dzire Tour 27 Dec 2016 Regis       Swift  tion  370000
# 432                             Tata zest x        Tata  odel  320000
# 433                            Mahindra xyl    Mahindra  2 bs  350000
# 441              Used Commercial Maruti Omn        Used  arry  150000
# 593  Commercial Chevrolet Sail Hatchback ca  Commercial  o...  225000
# ...

# %%
df['name']
# Out:
# 0        Hyundai Santro Xing XO eRLX Euro III
# 1                     Mahindra Jeep CL550 MDI
# 3      Hyundai Grand i10 Magna 1.2 Kappa VTVT
# 4            Ford EcoSport Titanium 1.5L TDCi
# 6                                   Ford Figo
#                         ...
# 887                                        Ta
# 888                       Tata Zest XM Diesel
# 889                        Mahindra Quanto C8
# 890                  Honda Amaze 1.2 E i VTEC
# 891                 Chevrolet Sail 1.2 LT ABS
# Name: name, Length: 857, dtype: object

# %%
df['name'].str.split().str.slice(0,3).str.join('')
# Out:
# 0         HyundaiSantroXing
# 1         MahindraJeepCL550
# 3           HyundaiGrandi10
# 4      FordEcoSportTitanium
# 6                  FordFigo
#                ...
# 887                      Ta
# 888              TataZestXM
# 889        MahindraQuantoC8
# 890           HondaAmaze1.2
# 891        ChevroletSail1.2
# Name: name, Length: 857, dtype: object

# %%
df.reset_index(drop=True)
# Out:
#                                        name    company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006  425000
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014  325000
# 3          Ford EcoSport Titanium 1.5L TDCi       Ford  2014  575000
# 4                                 Ford Figo       Ford  2012  175000
# ..                                      ...        ...   ...     ...
# 852                                      Ta       Tara  zest  310000
# 853                     Tata Zest XM Diesel       Tata  2018  260000
# 854                      Mahindra Quanto C8   Mahindra  2013  390000
# 855                Honda Amaze 1.2 E i VTEC      Honda  2014  180000
# 856               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  160000
#
#     kms_driven fuel_type
# 0       45,000    Petrol
# 1           40    Diesel
# 2       28,000    Petrol
# 3       36,000    Diesel
# ...

# %%
df.describe()
# Out:
#               Price
# count  8.570000e+02
# mean   4.046885e+05
# std    4.655365e+05
# min    3.000000e+04
# 25%    1.750000e+05
# 50%    2.999990e+05
# 75%    4.850000e+05
# max    8.500003e+06

# %%
df.to_csv('Cleaned_Car.csv')

# %%
X=df[['name','company','year','kms_driven','fuel_type']]
y=df['Price']

# %%
X
# Out:
#                                        name    company  year kms_driven  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007     45,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006         40
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014     28,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014     36,000
# 6                                 Ford Figo       Ford  2012     41,000
# ..                                      ...        ...   ...        ...
# 887                                      Ta       Tara  zest        NaN
# 888                     Tata Zest XM Diesel       Tata  2018     27,000
# 889                      Mahindra Quanto C8   Mahindra  2013     40,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014     Petrol
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014     Petrol
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 3      Petrol
# 4      Diesel
# 6      Diesel
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df = pd.DataFrame(df)

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding to 'name', 'company', and 'fuel_type' columns
df['name'] = label_encoder.fit_transform(df['name'])
df['company'] = label_encoder.fit_transform(df['company'])
df['fuel_type'] = label_encoder.fit_transform(df['fuel_type'])
print(df)
# Out:
#      name  company  year   Price kms_driven  fuel_type
# 0     147       12  2007   80000     45,000          2
# 1     194       18  2006  425000         40          0
# 3     136       12  2014  325000     28,000          2
# 4      56        9  2014  575000     36,000          0
# 6      63        9  2012  175000     41,000          0
# ..    ...      ...   ...     ...        ...        ...
# 887   392       29  zest  310000        NaN          3
# 888   443       30  2018  260000     27,000          0
# 889   202       18  2013  390000     40,000          0
# 890    77       11  2014  180000     Petrol          3
# 891    31        4  2014  160000     Petrol          3
#
# [857 rows x 6 columns]

# %%
#column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# Assume df is your dataframe with the relevant columns
# X = df[['name', 'company', 'year', 'kms_driven', 'fuel_type']]
# y = df['Price']

# Create OneHotEncoder for categorical columns
ohe = OneHotEncoder(sparse=False, drop='first')

# Encoding the categorical columns: 'name', 'company', and 'fuel_type'
X_categorical = df[['name', 'company', 'fuel_type']]
X_encoded = ohe.fit_transform(X_categorical)

# Create a new DataFrame for the categorical features after encoding
X_encoded_df = pd.DataFrame(X_encoded, columns=ohe.get_feature_names_out(X_categorical.columns))

# Combine encoded columns with the remaining numeric columns: 'year' and 'kms_driven'
X_numeric = df[['year', 'kms_driven']]
X_final = pd.concat([X_numeric.reset_index(drop=True), X_encoded_df.reset_index(drop=True)], axis=1)

# Splitting the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model (using Mean Squared Error as an example)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Optional: Display the coefficients of the regression
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-c9f82f39cbaa> in <cell line: 33>()
#      31
#      32 # Train the model
# ---> 33 model.fit(X_train, y_train)
#      34
#      35 # Make predictions on the test data
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
# ...

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder

# Assuming df is your dataframe and it contains X = ['name', 'company', 'year', 'kms_driven', 'fuel_type'] and y = 'Price'

# Separate the target variable
y = df['Price']

# OneHotEncode categorical columns: 'name', 'company', 'fuel_type'
X_categorical = df[['name', 'company', 'fuel_type']]

# Initialize OneHotEncoder
ohe = OneHotEncoder(sparse=False, drop='first')

# Fit and transform categorical columns
X_encoded = ohe.fit_transform(X_categorical)

# Create a DataFrame from the encoded features
X_encoded_df = pd.DataFrame(X_encoded, columns=ohe.get_feature_names_out(X_categorical.columns))

# Extract numeric columns: 'year', 'kms_driven'
X_numeric = df[['year', 'kms_driven']]

# Combine numeric columns and encoded categorical columns
X_final = pd.concat([X_numeric.reset_index(drop=True), X_encoded_df.reset_index(drop=True)], axis=1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42)

# Initialize the Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model using Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Optional: Display the coefficients of the regression
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-f148d7902e39> in <cell line: 38>()
#      36
#      37 # Train the model
# ---> 38 model.fit(X_train, y_train)
#      39
#      40 # Make predictions on the test data
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
# ...
